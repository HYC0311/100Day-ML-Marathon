# %% [markdown]
# ## Work
# 1. 請改變 reduce_lr 的 patience 和 factor 並比較不同設定下，對訓練/驗證集的影響
# 2. 請將 optimizer 換成 Adam、RMSprop 搭配 reduce_lr 並比較訓練結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(factor=0.3, 
                              min_lr=1e-12, 
                              monitor='val_loss', 
                              patience=10, 
                              verbose=1)

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[reduce_lr]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.2218 - acc: 0.2663 - val_loss: 2.0453 - val_acc: 0.3296
# Epoch 2/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.7471 - acc: 0.3927 - val_loss: 1.7882 - val_acc: 0.3894
# Epoch 3/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.6183 - acc: 0.4362 - val_loss: 1.7066 - val_acc: 0.4118
# Epoch 4/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.5432 - acc: 0.4611 - val_loss: 1.6280 - val_acc: 0.4373
# Epoch 5/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.4874 - acc: 0.4817 - val_loss: 1.5995 - val_acc: 0.4423
# Epoch 6/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.4453 - acc: 0.4949 - val_loss: 1.5820 - val_acc: 0.4428
# Epoch 7/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.4052 - acc: 0.5089 - val_loss: 1.5496 - val_acc: 0.4542
# Epoch 8/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.3696 - acc: 0.5236 - val_loss: 1.5443 - val_acc: 0.4555
# Epoch 9/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.3374 - acc: 0.5347 - val_loss: 1.5282 - val_acc: 0.4645
# Epoch 10/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.3080 - acc: 0.5452 - val_loss: 1.5153 - val_acc: 0.4690
# Epoch 11/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.2791 - acc: 0.5560 - val_loss: 1.5033 - val_acc: 0.4717
# Epoch 12/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.2498 - acc: 0.5671 - val_loss: 1.4895 - val_acc: 0.4784
# Epoch 13/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.2249 - acc: 0.5760 - val_loss: 1.4855 - val_acc: 0.4817
# Epoch 14/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.1994 - acc: 0.5856 - val_loss: 1.4777 - val_acc: 0.4803
# Epoch 15/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.1745 - acc: 0.5966 - val_loss: 1.4750 - val_acc: 0.4859
# Epoch 16/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.1534 - acc: 0.6027 - val_loss: 1.4714 - val_acc: 0.4898
# Epoch 17/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.1271 - acc: 0.6137 - val_loss: 1.4699 - val_acc: 0.4904
# Epoch 18/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.1032 - acc: 0.6212 - val_loss: 1.4699 - val_acc: 0.4864
# Epoch 19/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 1.0818 - acc: 0.6305 - val_loss: 1.4617 - val_acc: 0.4951
# Epoch 20/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.0597 - acc: 0.6387 - val_loss: 1.4717 - val_acc: 0.4938
# Epoch 21/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.0368 - acc: 0.6468 - val_loss: 1.4664 - val_acc: 0.4911
# Epoch 22/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.0152 - acc: 0.6567 - val_loss: 1.4646 - val_acc: 0.4942
# Epoch 23/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.9949 - acc: 0.6630 - val_loss: 1.4824 - val_acc: 0.4907
# Epoch 24/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.9711 - acc: 0.6727 - val_loss: 1.4677 - val_acc: 0.4911
# Epoch 25/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.9524 - acc: 0.6810 - val_loss: 1.4673 - val_acc: 0.4957
# Epoch 26/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.9324 - acc: 0.6881 - val_loss: 1.4717 - val_acc: 0.4997
# Epoch 27/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.9111 - acc: 0.6977 - val_loss: 1.4762 - val_acc: 0.4991
# Epoch 28/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8888 - acc: 0.7060 - val_loss: 1.4747 - val_acc: 0.4991
# Epoch 29/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8688 - acc: 0.7136 - val_loss: 1.4757 - val_acc: 0.4936
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 30/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.8412 - acc: 0.7257 - val_loss: 1.4710 - val_acc: 0.4986
# Epoch 31/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8192 - acc: 0.7358 - val_loss: 1.4643 - val_acc: 0.5025
# Epoch 32/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8105 - acc: 0.7399 - val_loss: 1.4690 - val_acc: 0.5057
# Epoch 33/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.8036 - acc: 0.7430 - val_loss: 1.4706 - val_acc: 0.5084
# Epoch 34/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7964 - acc: 0.7453 - val_loss: 1.4730 - val_acc: 0.5060
# Epoch 35/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7904 - acc: 0.7480 - val_loss: 1.4750 - val_acc: 0.5024
# Epoch 36/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7834 - acc: 0.7518 - val_loss: 1.4769 - val_acc: 0.5034
# Epoch 37/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7769 - acc: 0.7548 - val_loss: 1.4783 - val_acc: 0.5034
# Epoch 38/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7695 - acc: 0.7571 - val_loss: 1.4816 - val_acc: 0.5051
# Epoch 39/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7625 - acc: 0.7584 - val_loss: 1.4904 - val_acc: 0.5021
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 40/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7535 - acc: 0.7626 - val_loss: 1.4849 - val_acc: 0.5046
# Epoch 41/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7461 - acc: 0.7672 - val_loss: 1.4830 - val_acc: 0.5088
# Epoch 42/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 0.7429 - acc: 0.7682 - val_loss: 1.4841 - val_acc: 0.5068
# Epoch 43/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7420 - acc: 0.7690 - val_loss: 1.4886 - val_acc: 0.5061
# Epoch 44/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7396 - acc: 0.7693 - val_loss: 1.4864 - val_acc: 0.5052
# Epoch 45/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7380 - acc: 0.7691 - val_loss: 1.4859 - val_acc: 0.5047
# Epoch 46/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7354 - acc: 0.7715 - val_loss: 1.4884 - val_acc: 0.5068
# Epoch 47/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7335 - acc: 0.7709 - val_loss: 1.4887 - val_acc: 0.5076
# Epoch 48/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.7319 - acc: 0.7736 - val_loss: 1.4896 - val_acc: 0.5038
# Epoch 49/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7298 - acc: 0.7730 - val_loss: 1.4897 - val_acc: 0.5057
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 50/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7261 - acc: 0.7736 - val_loss: 1.4904 - val_acc: 0.5059

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer='adam')

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[reduce_lr]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.7692 - acc: 0.3879 - val_loss: 2.4465 - val_acc: 0.2863
# Epoch 2/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.4835 - acc: 0.4759 - val_loss: 1.9634 - val_acc: 0.3446
# Epoch 3/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.3812 - acc: 0.5121 - val_loss: 1.9276 - val_acc: 0.3405
# Epoch 4/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.3023 - acc: 0.5428 - val_loss: 2.3719 - val_acc: 0.2861
# Epoch 5/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.2413 - acc: 0.5627 - val_loss: 2.0719 - val_acc: 0.3197
# Epoch 6/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.1820 - acc: 0.5829 - val_loss: 1.9555 - val_acc: 0.3741
# Epoch 7/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.1312 - acc: 0.6016 - val_loss: 1.7010 - val_acc: 0.4135
# Epoch 8/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.0873 - acc: 0.6180 - val_loss: 1.6522 - val_acc: 0.4181
# Epoch 9/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.0506 - acc: 0.6323 - val_loss: 1.9992 - val_acc: 0.3602
# Epoch 10/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.9956 - acc: 0.6489 - val_loss: 2.0974 - val_acc: 0.3400
# Epoch 11/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.9659 - acc: 0.6615 - val_loss: 1.7477 - val_acc: 0.4251
# Epoch 12/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.9185 - acc: 0.6772 - val_loss: 1.6841 - val_acc: 0.4319
# Epoch 13/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.8964 - acc: 0.6866 - val_loss: 1.7948 - val_acc: 0.3959
# Epoch 14/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.8576 - acc: 0.6989 - val_loss: 2.0274 - val_acc: 0.4001
# Epoch 15/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.8240 - acc: 0.7116 - val_loss: 1.8842 - val_acc: 0.4094
# Epoch 16/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.7879 - acc: 0.7240 - val_loss: 1.8621 - val_acc: 0.4151
# Epoch 17/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.7473 - acc: 0.7393 - val_loss: 1.7891 - val_acc: 0.4311
# Epoch 18/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.7096 - acc: 0.7533 - val_loss: 1.8814 - val_acc: 0.4375
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 19/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5715 - acc: 0.8134 - val_loss: 1.5657 - val_acc: 0.5016
# Epoch 20/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5084 - acc: 0.8426 - val_loss: 1.5238 - val_acc: 0.5214
# Epoch 21/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.4778 - acc: 0.8536 - val_loss: 1.5003 - val_acc: 0.5240
# Epoch 22/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.4548 - acc: 0.8624 - val_loss: 1.6104 - val_acc: 0.5142
# Epoch 23/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.4324 - acc: 0.8704 - val_loss: 1.5820 - val_acc: 0.5206
# Epoch 24/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.4135 - acc: 0.8794 - val_loss: 1.6482 - val_acc: 0.5075
# Epoch 25/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3906 - acc: 0.8866 - val_loss: 1.6638 - val_acc: 0.5130
# Epoch 26/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.3704 - acc: 0.8938 - val_loss: 1.6611 - val_acc: 0.5096
# Epoch 27/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.3492 - acc: 0.9021 - val_loss: 1.7495 - val_acc: 0.5069
# Epoch 28/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3369 - acc: 0.9061 - val_loss: 1.7995 - val_acc: 0.5061
# Epoch 29/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3157 - acc: 0.9140 - val_loss: 1.7807 - val_acc: 0.5052
# Epoch 30/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2968 - acc: 0.9208 - val_loss: 1.7944 - val_acc: 0.5072
# Epoch 31/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.2810 - acc: 0.9267 - val_loss: 1.8262 - val_acc: 0.4967
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 32/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2294 - acc: 0.9513 - val_loss: 1.7676 - val_acc: 0.5260
# Epoch 33/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2120 - acc: 0.9592 - val_loss: 1.7574 - val_acc: 0.5255
# Epoch 34/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2048 - acc: 0.9622 - val_loss: 1.7683 - val_acc: 0.5225
# Epoch 35/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1993 - acc: 0.9631 - val_loss: 1.7892 - val_acc: 0.5219
# Epoch 36/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1934 - acc: 0.9649 - val_loss: 1.7929 - val_acc: 0.5223
# Epoch 37/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 0.1898 - acc: 0.9660 - val_loss: 1.8239 - val_acc: 0.5220
# Epoch 38/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1833 - acc: 0.9689 - val_loss: 1.8311 - val_acc: 0.5220
# Epoch 39/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1784 - acc: 0.9696 - val_loss: 1.8552 - val_acc: 0.5245
# Epoch 40/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.1738 - acc: 0.9717 - val_loss: 1.8365 - val_acc: 0.5183
# Epoch 41/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.1676 - acc: 0.9726 - val_loss: 1.8923 - val_acc: 0.5197
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 42/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.1560 - acc: 0.9780 - val_loss: 1.8690 - val_acc: 0.5252
# Epoch 43/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1527 - acc: 0.9789 - val_loss: 1.8662 - val_acc: 0.5275
# Epoch 44/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1508 - acc: 0.9792 - val_loss: 1.8776 - val_acc: 0.5225
# Epoch 45/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1495 - acc: 0.9800 - val_loss: 1.8811 - val_acc: 0.5222
# Epoch 46/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1476 - acc: 0.9809 - val_loss: 1.8781 - val_acc: 0.5259
# Epoch 47/50
# 50000/50000 [==============================] - 4s 86us/step - loss: 0.1461 - acc: 0.9810 - val_loss: 1.8945 - val_acc: 0.5235
# Epoch 48/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1445 - acc: 0.9813 - val_loss: 1.8965 - val_acc: 0.5247
# Epoch 49/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1434 - acc: 0.9814 - val_loss: 1.8937 - val_acc: 0.5236
# Epoch 50/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1412 - acc: 0.9820 - val_loss: 1.8993 - val_acc: 0.5238
