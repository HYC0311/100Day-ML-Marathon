# %% [markdown]
# ## Work
# 1. 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
"""
Set your hyper-parameters
"""
LEARNING_RATE = 0.001
EPOCHS = 30
BATCH_SIZE = 512
MOMENTUM = [0.5, 1.0, 1.5]

# %%
lr=LEARNING_RATE
results = {}
for mm in MOMENTUM:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with LR = %.6f" % (lr))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=lr, nesterov=True, momentum=mm)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["acc"]
    valid_acc = model.history.history["val_acc"]
    
    exp_name_tag = "exp-mm-%s" % str(mm)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with LR = 0.001000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 4s 82us/step - loss: 2.2575 - acc: 0.1654 - val_loss: 2.1974 - val_acc: 0.2167
# Epoch 2/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 2.1557 - acc: 0.2417 - val_loss: 2.1221 - val_acc: 0.2469
# Epoch 3/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 2.0924 - acc: 0.2636 - val_loss: 2.0699 - val_acc: 0.2655
# Epoch 4/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 2.0471 - acc: 0.2804 - val_loss: 2.0308 - val_acc: 0.2816
# Epoch 5/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 2.0119 - acc: 0.2925 - val_loss: 1.9988 - val_acc: 0.2991
# Epoch 6/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.9836 - acc: 0.3049 - val_loss: 1.9733 - val_acc: 0.3130
# Epoch 7/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.9597 - acc: 0.3155 - val_loss: 1.9513 - val_acc: 0.3242
# Epoch 8/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.9394 - acc: 0.3236 - val_loss: 1.9323 - val_acc: 0.3298
# Epoch 9/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.9215 - acc: 0.3315 - val_loss: 1.9159 - val_acc: 0.3350
# Epoch 10/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.9060 - acc: 0.3375 - val_loss: 1.9009 - val_acc: 0.3393
# Epoch 11/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.8921 - acc: 0.3415 - val_loss: 1.8885 - val_acc: 0.3418
# Epoch 12/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.8799 - acc: 0.3451 - val_loss: 1.8765 - val_acc: 0.3501
# Epoch 13/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.8686 - acc: 0.3505 - val_loss: 1.8654 - val_acc: 0.3532
# Epoch 14/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.8580 - acc: 0.3537 - val_loss: 1.8569 - val_acc: 0.3531
# Epoch 15/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.8484 - acc: 0.3562 - val_loss: 1.8470 - val_acc: 0.3611
# Epoch 16/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.8394 - acc: 0.3593 - val_loss: 1.8379 - val_acc: 0.3601
# Epoch 17/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.8308 - acc: 0.3627 - val_loss: 1.8298 - val_acc: 0.3628
# Epoch 18/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.8230 - acc: 0.3654 - val_loss: 1.8226 - val_acc: 0.3675
# Epoch 19/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.8156 - acc: 0.3667 - val_loss: 1.8154 - val_acc: 0.3698
# Epoch 20/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.8086 - acc: 0.3688 - val_loss: 1.8086 - val_acc: 0.3717
# Epoch 21/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.8016 - acc: 0.3713 - val_loss: 1.8021 - val_acc: 0.3727
# Epoch 22/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.7954 - acc: 0.3739 - val_loss: 1.7950 - val_acc: 0.3744
# Epoch 23/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.7890 - acc: 0.3754 - val_loss: 1.7897 - val_acc: 0.3763
# Epoch 24/30
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.7831 - acc: 0.3784 - val_loss: 1.7838 - val_acc: 0.3801
# Epoch 25/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.7768 - acc: 0.3809 - val_loss: 1.7799 - val_acc: 0.3805
# Epoch 26/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.7713 - acc: 0.3812 - val_loss: 1.7723 - val_acc: 0.3841
# Epoch 27/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.7662 - acc: 0.3844 - val_loss: 1.7668 - val_acc: 0.3834
# Epoch 28/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.7605 - acc: 0.3864 - val_loss: 1.7622 - val_acc: 0.3871
# Epoch 29/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.7554 - acc: 0.3877 - val_loss: 1.7566 - val_acc: 0.3886
# Epoch 30/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.7507 - acc: 0.3891 - val_loss: 1.7528 - val_acc: 0.3892
# Experiment with LR = 0.001000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 4s 82us/step - loss: 2.1156 - acc: 0.2356 - val_loss: 1.9525 - val_acc: 0.3066
# Epoch 2/30
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.8800 - acc: 0.3437 - val_loss: 1.8349 - val_acc: 0.3489
# Epoch 3/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.8206 - acc: 0.3600 - val_loss: 1.8075 - val_acc: 0.3704
# Epoch 4/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.7333 - acc: 0.3934 - val_loss: 1.6947 - val_acc: 0.4017
# Epoch 5/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.6610 - acc: 0.4132 - val_loss: 1.6628 - val_acc: 0.4185
# Epoch 6/30
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.6242 - acc: 0.4301 - val_loss: 1.6219 - val_acc: 0.4287
# Epoch 7/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.5938 - acc: 0.4380 - val_loss: 1.6035 - val_acc: 0.4386
# Epoch 8/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.5661 - acc: 0.4487 - val_loss: 1.6216 - val_acc: 0.4285
# Epoch 9/30
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.5501 - acc: 0.4551 - val_loss: 1.5915 - val_acc: 0.4379
# Epoch 10/30
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.5315 - acc: 0.4591 - val_loss: 1.5538 - val_acc: 0.4517
# Epoch 11/30
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.5163 - acc: 0.4665 - val_loss: 1.5476 - val_acc: 0.4552
# Epoch 12/30
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.5041 - acc: 0.4702 - val_loss: 1.5474 - val_acc: 0.4541
# Epoch 13/30
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.4948 - acc: 0.4727 - val_loss: 1.5289 - val_acc: 0.4667
# Epoch 14/30
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.4790 - acc: 0.4807 - val_loss: 1.5049 - val_acc: 0.4677
# Epoch 15/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4653 - acc: 0.4835 - val_loss: 1.5094 - val_acc: 0.4704
# Epoch 16/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4621 - acc: 0.4847 - val_loss: 1.5056 - val_acc: 0.4685
# Epoch 17/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4525 - acc: 0.4885 - val_loss: 1.5130 - val_acc: 0.4654
# Epoch 18/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.4533 - acc: 0.4838 - val_loss: 1.5107 - val_acc: 0.4720
# Epoch 19/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.4406 - acc: 0.4928 - val_loss: 1.5023 - val_acc: 0.4684
# Epoch 20/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4329 - acc: 0.4954 - val_loss: 1.4867 - val_acc: 0.4737
# Epoch 21/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4237 - acc: 0.5005 - val_loss: 1.4962 - val_acc: 0.4777
# Epoch 22/30
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.4210 - acc: 0.4988 - val_loss: 1.5185 - val_acc: 0.4714
# Epoch 23/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4276 - acc: 0.4989 - val_loss: 1.4970 - val_acc: 0.4813
# Epoch 24/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4202 - acc: 0.4995 - val_loss: 1.5058 - val_acc: 0.4748
# Epoch 25/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4142 - acc: 0.5017 - val_loss: 1.5050 - val_acc: 0.4771
# Epoch 26/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.4133 - acc: 0.5036 - val_loss: 1.5006 - val_acc: 0.4741
# Epoch 27/30
# 50000/50000 [==============================] - 4s 78us/step - loss: 1.3993 - acc: 0.5072 - val_loss: 1.4844 - val_acc: 0.4717
# Epoch 28/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.3940 - acc: 0.5079 - val_loss: 1.4843 - val_acc: 0.4759
# Epoch 29/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.3845 - acc: 0.5136 - val_loss: 1.4933 - val_acc: 0.4770
# Epoch 30/30
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.3752 - acc: 0.5135 - val_loss: 1.4797 - val_acc: 0.4767
# Experiment with LR = 0.001000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 4s 81us/step - loss: nan - acc: 0.1051 - val_loss: nan - val_acc: 0.1000
# Epoch 2/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 3/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 4/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 5/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 6/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 7/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 8/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 9/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 10/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 11/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 12/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 13/30
# 50000/50000 [==============================] - 4s 79us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 14/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 15/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 16/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 17/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 18/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 19/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 20/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 21/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 22/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 23/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 24/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 25/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 26/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 27/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 28/30
# 50000/50000 [==============================] - 4s 77us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 29/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000
# Epoch 30/30
# 50000/50000 [==============================] - 4s 78us/step - loss: nan - acc: 0.1000 - val_loss: nan - val_acc: 0.1000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8, 6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
