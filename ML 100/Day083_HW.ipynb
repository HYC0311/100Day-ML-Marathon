# %% [markdown]
# ## Work
# 1. 試比較有 BN 在 Batch_size = 2, 16, 32, 128, 256 下的差異
# 2. 請嘗試將 BN 放在 Activation 之前，並比較訓練結果
# 3. 請於 BN 放在 Input Layer 後，並比較結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 0.005
EPOCHS = 50
BATCH_SIZE0 = [256,512,1024]
MOMENTUM = 0.95

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=10, 
          batch_size=256, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.7034 - acc: 0.4061 - val_loss: 1.6720 - val_acc: 0.3921
# Epoch 2/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.4455 - acc: 0.4885 - val_loss: 1.5576 - val_acc: 0.4427
# Epoch 3/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.3476 - acc: 0.5245 - val_loss: 1.5230 - val_acc: 0.4532
# Epoch 4/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.2735 - acc: 0.5497 - val_loss: 1.6372 - val_acc: 0.4297
# Epoch 5/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.2130 - acc: 0.5701 - val_loss: 1.6288 - val_acc: 0.4294
# Epoch 6/10
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.1602 - acc: 0.5894 - val_loss: 1.5143 - val_acc: 0.4543
# Epoch 7/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.1110 - acc: 0.6066 - val_loss: 1.5977 - val_acc: 0.4439
# Epoch 8/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.0655 - acc: 0.6233 - val_loss: 1.5859 - val_acc: 0.4684
# Epoch 9/10
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.0277 - acc: 0.6362 - val_loss: 1.7283 - val_acc: 0.4188
# Epoch 10/10
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.9924 - acc: 0.6465 - val_loss: 1.6915 - val_acc: 0.4435

# %%
results = {}
for BATCH_SIZE in BATCH_SIZE0:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer='adam')

    model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["acc"]
    valid_acc = model.history.history["val_acc"]
    
    exp_name_tag = "BATCH_SIZE-%s" % str(BATCH_SIZE)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 8s 152us/step - loss: 1.6928 - acc: 0.4046 - val_loss: 1.9315 - val_acc: 0.3466
# Epoch 2/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.4678 - acc: 0.4801 - val_loss: 2.1418 - val_acc: 0.2953
# Epoch 3/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.3772 - acc: 0.5127 - val_loss: 1.9110 - val_acc: 0.3532
# Epoch 4/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 1.3120 - acc: 0.5345 - val_loss: 1.8287 - val_acc: 0.3944
# Epoch 5/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.2481 - acc: 0.5583 - val_loss: 1.6546 - val_acc: 0.4284
# Epoch 6/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 1.2009 - acc: 0.5739 - val_loss: 1.8999 - val_acc: 0.3499
# Epoch 7/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.1568 - acc: 0.5886 - val_loss: 1.5571 - val_acc: 0.4605
# Epoch 8/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.1077 - acc: 0.6075 - val_loss: 1.6559 - val_acc: 0.4428
# Epoch 9/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.0644 - acc: 0.6232 - val_loss: 1.5179 - val_acc: 0.4759
# Epoch 10/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.0304 - acc: 0.6333 - val_loss: 1.6286 - val_acc: 0.4468
# Epoch 11/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.9958 - acc: 0.6474 - val_loss: 1.6619 - val_acc: 0.4362
# Epoch 12/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.9542 - acc: 0.6619 - val_loss: 1.5334 - val_acc: 0.4937
# Epoch 13/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.9225 - acc: 0.6736 - val_loss: 1.6663 - val_acc: 0.4439
# Epoch 14/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.8966 - acc: 0.6798 - val_loss: 1.6773 - val_acc: 0.4440
# Epoch 15/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.8556 - acc: 0.6969 - val_loss: 1.6956 - val_acc: 0.4665
# Epoch 16/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.8241 - acc: 0.7067 - val_loss: 1.7538 - val_acc: 0.4566
# Epoch 17/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.7977 - acc: 0.7174 - val_loss: 1.6457 - val_acc: 0.4779
# Epoch 18/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.7605 - acc: 0.7302 - val_loss: 1.7799 - val_acc: 0.4637
# Epoch 19/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.7311 - acc: 0.7427 - val_loss: 1.8840 - val_acc: 0.4425
# Epoch 20/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.6994 - acc: 0.7541 - val_loss: 1.7206 - val_acc: 0.4812
# Epoch 21/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.6799 - acc: 0.7578 - val_loss: 1.7670 - val_acc: 0.4800
# Epoch 22/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.6487 - acc: 0.7703 - val_loss: 1.7500 - val_acc: 0.4920
# Epoch 23/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.6227 - acc: 0.7780 - val_loss: 1.9566 - val_acc: 0.4602
# Epoch 24/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.5956 - acc: 0.7902 - val_loss: 1.7846 - val_acc: 0.4995
# Epoch 25/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.5697 - acc: 0.7990 - val_loss: 1.8587 - val_acc: 0.4873
# Epoch 26/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.5489 - acc: 0.8043 - val_loss: 2.0867 - val_acc: 0.4602
# Epoch 27/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.5224 - acc: 0.8176 - val_loss: 2.0190 - val_acc: 0.4649
# Epoch 28/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.5048 - acc: 0.8207 - val_loss: 1.9349 - val_acc: 0.4963
# Epoch 29/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.4877 - acc: 0.8264 - val_loss: 1.9570 - val_acc: 0.4860
# Epoch 30/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.4594 - acc: 0.8389 - val_loss: 2.2426 - val_acc: 0.4623
# Epoch 31/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.4450 - acc: 0.8425 - val_loss: 2.2627 - val_acc: 0.4650
# Epoch 32/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.4239 - acc: 0.8484 - val_loss: 2.1823 - val_acc: 0.4918
# Epoch 33/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.4105 - acc: 0.8546 - val_loss: 2.5241 - val_acc: 0.4611
# Epoch 34/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.4074 - acc: 0.8547 - val_loss: 2.2991 - val_acc: 0.4726
# Epoch 35/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.3755 - acc: 0.8671 - val_loss: 2.5619 - val_acc: 0.4388
# Epoch 36/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.3714 - acc: 0.8687 - val_loss: 2.3082 - val_acc: 0.4891
# Epoch 37/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.3587 - acc: 0.8727 - val_loss: 2.3989 - val_acc: 0.4799
# Epoch 38/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.3357 - acc: 0.8822 - val_loss: 2.5406 - val_acc: 0.4614
# Epoch 39/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.3289 - acc: 0.8834 - val_loss: 2.4078 - val_acc: 0.4882
# Epoch 40/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.3238 - acc: 0.8849 - val_loss: 2.4865 - val_acc: 0.4882
# Epoch 41/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.3102 - acc: 0.8896 - val_loss: 2.8218 - val_acc: 0.4547
# Epoch 42/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.2987 - acc: 0.8940 - val_loss: 2.9629 - val_acc: 0.4448
# Epoch 43/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.2874 - acc: 0.8964 - val_loss: 2.7472 - val_acc: 0.4707
# Epoch 44/50
# 50000/50000 [==============================] - 7s 137us/step - loss: 0.2844 - acc: 0.8982 - val_loss: 2.6739 - val_acc: 0.4590
# Epoch 45/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.2674 - acc: 0.9056 - val_loss: 2.7187 - val_acc: 0.4791
# Epoch 46/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.2582 - acc: 0.9090 - val_loss: 2.9599 - val_acc: 0.4562
# Epoch 47/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 0.2493 - acc: 0.9120 - val_loss: 2.9063 - val_acc: 0.4661
# Epoch 48/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 0.2603 - acc: 0.9064 - val_loss: 2.8297 - val_acc: 0.4647
# Epoch 49/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.2462 - acc: 0.9123 - val_loss: 2.8002 - val_acc: 0.4831
# Epoch 50/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 0.2329 - acc: 0.9181 - val_loss: 3.0016 - val_acc: 0.4647
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 117us/step - loss: 1.7219 - acc: 0.3983 - val_loss: 1.8123 - val_acc: 0.3640
# Epoch 2/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.4700 - acc: 0.4811 - val_loss: 1.8778 - val_acc: 0.3547
# Epoch 3/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.3657 - acc: 0.5157 - val_loss: 2.0314 - val_acc: 0.3139
# Epoch 4/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.2930 - acc: 0.5435 - val_loss: 1.6529 - val_acc: 0.4229
# Epoch 5/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.2360 - acc: 0.5650 - val_loss: 1.8991 - val_acc: 0.3596
# Epoch 6/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.1863 - acc: 0.5803 - val_loss: 1.9663 - val_acc: 0.3530
# Epoch 7/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.1299 - acc: 0.6001 - val_loss: 2.0246 - val_acc: 0.3401
# Epoch 8/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.0956 - acc: 0.6133 - val_loss: 2.1273 - val_acc: 0.3218
# Epoch 9/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.0617 - acc: 0.6250 - val_loss: 2.9114 - val_acc: 0.2717
# Epoch 10/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.0198 - acc: 0.6381 - val_loss: 1.7330 - val_acc: 0.4245
# Epoch 11/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.9780 - acc: 0.6553 - val_loss: 1.7021 - val_acc: 0.4302
# Epoch 12/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.9488 - acc: 0.6654 - val_loss: 1.7320 - val_acc: 0.4252
# Epoch 13/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.9153 - acc: 0.6743 - val_loss: 1.9980 - val_acc: 0.3904
# Epoch 14/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.8827 - acc: 0.6890 - val_loss: 1.8965 - val_acc: 0.4202
# Epoch 15/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.8402 - acc: 0.7050 - val_loss: 1.7738 - val_acc: 0.4239
# Epoch 16/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.7995 - acc: 0.7184 - val_loss: 1.8585 - val_acc: 0.4272
# Epoch 17/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.7696 - acc: 0.7313 - val_loss: 1.8017 - val_acc: 0.4295
# Epoch 18/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.7325 - acc: 0.7430 - val_loss: 1.7735 - val_acc: 0.4491
# Epoch 19/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.7090 - acc: 0.7517 - val_loss: 2.0617 - val_acc: 0.4034
# Epoch 20/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.6706 - acc: 0.7647 - val_loss: 1.8429 - val_acc: 0.4556
# Epoch 21/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.6424 - acc: 0.7736 - val_loss: 1.8491 - val_acc: 0.4535
# Epoch 22/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.6200 - acc: 0.7830 - val_loss: 1.9149 - val_acc: 0.4469
# Epoch 23/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.5808 - acc: 0.7962 - val_loss: 1.9561 - val_acc: 0.4541
# Epoch 24/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.5494 - acc: 0.8086 - val_loss: 2.0265 - val_acc: 0.4462
# Epoch 25/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.5183 - acc: 0.8202 - val_loss: 2.0033 - val_acc: 0.4525
# Epoch 26/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.4986 - acc: 0.8272 - val_loss: 2.0224 - val_acc: 0.4496
# Epoch 27/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.4666 - acc: 0.8390 - val_loss: 2.2689 - val_acc: 0.4424
# Epoch 28/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.4444 - acc: 0.8460 - val_loss: 2.1555 - val_acc: 0.4616
# Epoch 29/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.4138 - acc: 0.8552 - val_loss: 2.0852 - val_acc: 0.4814
# Epoch 30/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.3823 - acc: 0.8680 - val_loss: 2.2506 - val_acc: 0.4609
# Epoch 31/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.3788 - acc: 0.8692 - val_loss: 2.4600 - val_acc: 0.4407
# Epoch 32/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.3542 - acc: 0.8779 - val_loss: 2.3382 - val_acc: 0.4686
# Epoch 33/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.3406 - acc: 0.8815 - val_loss: 2.4988 - val_acc: 0.4391
# Epoch 34/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.3186 - acc: 0.8915 - val_loss: 2.4068 - val_acc: 0.4610
# Epoch 35/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.2916 - acc: 0.9001 - val_loss: 2.5160 - val_acc: 0.4473
# Epoch 36/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2813 - acc: 0.9042 - val_loss: 2.4292 - val_acc: 0.4704
# Epoch 37/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.2810 - acc: 0.9036 - val_loss: 2.4566 - val_acc: 0.4621
# Epoch 38/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.2599 - acc: 0.9105 - val_loss: 2.7278 - val_acc: 0.4553
# Epoch 39/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2487 - acc: 0.9153 - val_loss: 2.6996 - val_acc: 0.4541
# Epoch 40/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.2411 - acc: 0.9172 - val_loss: 2.8549 - val_acc: 0.4517
# Epoch 41/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.2217 - acc: 0.9264 - val_loss: 2.8934 - val_acc: 0.4554
# Epoch 42/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.2019 - acc: 0.9328 - val_loss: 2.8273 - val_acc: 0.4711
# Epoch 43/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.1917 - acc: 0.9358 - val_loss: 2.7840 - val_acc: 0.4671
# Epoch 44/50
# 50000/50000 [==============================] - 6s 110us/step - loss: 0.2023 - acc: 0.9296 - val_loss: 2.8689 - val_acc: 0.4635
# Epoch 45/50
# 50000/50000 [==============================] - 6s 111us/step - loss: 0.1967 - acc: 0.9333 - val_loss: 2.7955 - val_acc: 0.4623
# Epoch 46/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.1903 - acc: 0.9349 - val_loss: 3.2054 - val_acc: 0.4412
# Epoch 47/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.1713 - acc: 0.9423 - val_loss: 3.0859 - val_acc: 0.4604
# Epoch 48/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.1618 - acc: 0.9460 - val_loss: 3.0128 - val_acc: 0.4766
# Epoch 49/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.1507 - acc: 0.9504 - val_loss: 3.1581 - val_acc: 0.4607
# Epoch 50/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.1521 - acc: 0.9489 - val_loss: 3.1446 - val_acc: 0.4558
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.7715 - acc: 0.3830 - val_loss: 2.0058 - val_acc: 0.3357
# Epoch 2/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.4945 - acc: 0.4742 - val_loss: 1.9251 - val_acc: 0.3616
# Epoch 3/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.3860 - acc: 0.5121 - val_loss: 1.8205 - val_acc: 0.3613
# Epoch 4/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.3092 - acc: 0.5391 - val_loss: 1.9666 - val_acc: 0.3497
# Epoch 5/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.2516 - acc: 0.5612 - val_loss: 2.3596 - val_acc: 0.2758
# Epoch 6/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.1875 - acc: 0.5841 - val_loss: 1.9561 - val_acc: 0.3786
# Epoch 7/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.1398 - acc: 0.6011 - val_loss: 1.7701 - val_acc: 0.4032
# Epoch 8/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.0892 - acc: 0.6188 - val_loss: 1.7148 - val_acc: 0.4149
# Epoch 9/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.0551 - acc: 0.6293 - val_loss: 1.6762 - val_acc: 0.4148
# Epoch 10/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.0113 - acc: 0.6473 - val_loss: 1.8248 - val_acc: 0.3897
# Epoch 11/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.9740 - acc: 0.6589 - val_loss: 2.1622 - val_acc: 0.3626
# Epoch 12/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.9261 - acc: 0.6753 - val_loss: 2.1834 - val_acc: 0.3454
# Epoch 13/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.8900 - acc: 0.6883 - val_loss: 1.8876 - val_acc: 0.4030
# Epoch 14/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.8617 - acc: 0.6995 - val_loss: 2.0552 - val_acc: 0.3806
# Epoch 15/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.8285 - acc: 0.7108 - val_loss: 2.2406 - val_acc: 0.3666
# Epoch 16/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.7905 - acc: 0.7241 - val_loss: 2.0212 - val_acc: 0.4160
# Epoch 17/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.7500 - acc: 0.7378 - val_loss: 1.9252 - val_acc: 0.4194
# Epoch 18/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.7100 - acc: 0.7552 - val_loss: 1.9593 - val_acc: 0.4248
# Epoch 19/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.6809 - acc: 0.7628 - val_loss: 1.8321 - val_acc: 0.4461
# Epoch 20/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.6396 - acc: 0.7786 - val_loss: 1.9191 - val_acc: 0.4235
# Epoch 21/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.6136 - acc: 0.7884 - val_loss: 2.2352 - val_acc: 0.4038
# Epoch 22/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.5985 - acc: 0.7923 - val_loss: 2.1162 - val_acc: 0.4308
# Epoch 23/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.5691 - acc: 0.8036 - val_loss: 2.1674 - val_acc: 0.4100
# Epoch 24/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.5211 - acc: 0.8241 - val_loss: 2.0543 - val_acc: 0.4465
# Epoch 25/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.5003 - acc: 0.8302 - val_loss: 2.3333 - val_acc: 0.4353
# Epoch 26/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.4638 - acc: 0.8429 - val_loss: 2.4294 - val_acc: 0.4006
# Epoch 27/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.4432 - acc: 0.8495 - val_loss: 2.1197 - val_acc: 0.4686
# Epoch 28/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.4080 - acc: 0.8642 - val_loss: 2.3086 - val_acc: 0.4386
# Epoch 29/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.3943 - acc: 0.8665 - val_loss: 2.3735 - val_acc: 0.4174
# Epoch 30/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3765 - acc: 0.8739 - val_loss: 2.5958 - val_acc: 0.4041
# Epoch 31/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3524 - acc: 0.8822 - val_loss: 2.6158 - val_acc: 0.4181
# Epoch 32/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3350 - acc: 0.8871 - val_loss: 2.3644 - val_acc: 0.4538
# Epoch 33/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.3117 - acc: 0.8967 - val_loss: 2.6791 - val_acc: 0.4298
# Epoch 34/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.3022 - acc: 0.8985 - val_loss: 2.9263 - val_acc: 0.4334
# Epoch 35/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2738 - acc: 0.9109 - val_loss: 2.5864 - val_acc: 0.4381
# Epoch 36/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.2535 - acc: 0.9184 - val_loss: 2.8667 - val_acc: 0.4411
# Epoch 37/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2423 - acc: 0.9219 - val_loss: 2.6512 - val_acc: 0.4373
# Epoch 38/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.2138 - acc: 0.9337 - val_loss: 2.6510 - val_acc: 0.4533
# Epoch 39/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.2030 - acc: 0.9364 - val_loss: 2.5229 - val_acc: 0.4527
# Epoch 40/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.1923 - acc: 0.9398 - val_loss: 2.7108 - val_acc: 0.4623
# Epoch 41/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1760 - acc: 0.9470 - val_loss: 2.7177 - val_acc: 0.4533
# Epoch 42/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1662 - acc: 0.9486 - val_loss: 2.7813 - val_acc: 0.4632
# Epoch 43/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1733 - acc: 0.9448 - val_loss: 2.8675 - val_acc: 0.4554
# Epoch 44/50
# 50000/50000 [==============================] - 5s 90us/step - loss: 0.1635 - acc: 0.9488 - val_loss: 2.8131 - val_acc: 0.4668
# Epoch 45/50
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.1491 - acc: 0.9537 - val_loss: 2.7782 - val_acc: 0.4674
# Epoch 46/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1369 - acc: 0.9596 - val_loss: 2.8860 - val_acc: 0.4811
# Epoch 47/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1277 - acc: 0.9612 - val_loss: 3.1165 - val_acc: 0.4376
# Epoch 48/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1255 - acc: 0.9627 - val_loss: 2.9641 - val_acc: 0.4614
# Epoch 49/50
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.1112 - acc: 0.9678 - val_loss: 2.9168 - val_acc: 0.4809
# Epoch 50/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 0.1073 - acc: 0.9685 - val_loss: 3.0531 - val_acc: 0.4771

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8, 6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = BatchNormalization()(x)
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
BATCH_SIZE=1024
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,741,962
# Trainable params: 1,740,426
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.8968 - acc: 0.3379 - val_loss: 1.9978 - val_acc: 0.3254
# Epoch 2/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.5647 - acc: 0.4519 - val_loss: 1.7228 - val_acc: 0.3957
# Epoch 3/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 1.4473 - acc: 0.4940 - val_loss: 1.5617 - val_acc: 0.4510
# Epoch 4/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.3706 - acc: 0.5182 - val_loss: 1.5521 - val_acc: 0.4495
# Epoch 5/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.3092 - acc: 0.5429 - val_loss: 1.4989 - val_acc: 0.4678
# Epoch 6/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.2533 - acc: 0.5607 - val_loss: 1.4802 - val_acc: 0.4746
# Epoch 7/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.2063 - acc: 0.5781 - val_loss: 1.4731 - val_acc: 0.4681
# Epoch 8/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.1589 - acc: 0.5959 - val_loss: 1.4451 - val_acc: 0.4888
# Epoch 9/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.1108 - acc: 0.6137 - val_loss: 1.4517 - val_acc: 0.4860
# Epoch 10/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 1.0664 - acc: 0.6317 - val_loss: 1.4376 - val_acc: 0.5006
# Epoch 11/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 1.0254 - acc: 0.6462 - val_loss: 1.4825 - val_acc: 0.4787
# Epoch 12/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.9841 - acc: 0.6607 - val_loss: 1.4155 - val_acc: 0.5039
# Epoch 13/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.9434 - acc: 0.6755 - val_loss: 1.4952 - val_acc: 0.4870
# Epoch 14/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.9038 - acc: 0.6916 - val_loss: 1.4306 - val_acc: 0.5025
# Epoch 15/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.8626 - acc: 0.7086 - val_loss: 1.4763 - val_acc: 0.5020
# Epoch 16/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.8255 - acc: 0.7194 - val_loss: 1.4847 - val_acc: 0.5001
# Epoch 17/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.7852 - acc: 0.7360 - val_loss: 1.5605 - val_acc: 0.4834
# Epoch 18/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.7517 - acc: 0.7490 - val_loss: 1.4956 - val_acc: 0.5052
# Epoch 19/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.7123 - acc: 0.7645 - val_loss: 1.5261 - val_acc: 0.5060
# Epoch 20/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.6765 - acc: 0.7778 - val_loss: 1.5204 - val_acc: 0.5020
# Epoch 21/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.6355 - acc: 0.7961 - val_loss: 1.6005 - val_acc: 0.4908
# Epoch 22/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.6042 - acc: 0.8032 - val_loss: 1.5806 - val_acc: 0.4947
# Epoch 23/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.5664 - acc: 0.8185 - val_loss: 1.6023 - val_acc: 0.4984
# Epoch 24/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.5316 - acc: 0.8314 - val_loss: 1.6602 - val_acc: 0.4888
# Epoch 25/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.4984 - acc: 0.8444 - val_loss: 1.6873 - val_acc: 0.4934
# Epoch 26/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.4680 - acc: 0.8535 - val_loss: 1.7640 - val_acc: 0.4984
# Epoch 27/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.4332 - acc: 0.8693 - val_loss: 1.7221 - val_acc: 0.4994
# Epoch 28/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.4028 - acc: 0.8801 - val_loss: 1.9385 - val_acc: 0.4757
# Epoch 29/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.3782 - acc: 0.8904 - val_loss: 1.8989 - val_acc: 0.4825
# Epoch 30/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.3481 - acc: 0.8995 - val_loss: 1.9814 - val_acc: 0.4851
# Epoch 31/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.3227 - acc: 0.9086 - val_loss: 1.8933 - val_acc: 0.4941
# Epoch 32/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.2999 - acc: 0.9164 - val_loss: 1.9772 - val_acc: 0.4948
# Epoch 33/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.2678 - acc: 0.9306 - val_loss: 1.9756 - val_acc: 0.4922
# Epoch 34/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.2477 - acc: 0.9351 - val_loss: 1.9599 - val_acc: 0.5001
# Epoch 35/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.2270 - acc: 0.9435 - val_loss: 2.0738 - val_acc: 0.4997
# Epoch 36/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.2065 - acc: 0.9500 - val_loss: 2.1019 - val_acc: 0.4871
# Epoch 37/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.1930 - acc: 0.9545 - val_loss: 2.1823 - val_acc: 0.4866
# Epoch 38/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.1774 - acc: 0.9595 - val_loss: 2.3025 - val_acc: 0.4814
# Epoch 39/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.1586 - acc: 0.9654 - val_loss: 2.1891 - val_acc: 0.4938
# Epoch 40/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.1426 - acc: 0.9708 - val_loss: 2.2042 - val_acc: 0.5002
# Epoch 41/50
# 50000/50000 [==============================] - 4s 80us/step - loss: 0.1313 - acc: 0.9737 - val_loss: 2.3923 - val_acc: 0.4890
# Epoch 42/50
# 50000/50000 [==============================] - 4s 83us/step - loss: 0.1189 - acc: 0.9776 - val_loss: 2.3183 - val_acc: 0.4948
# Epoch 43/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 0.1070 - acc: 0.9816 - val_loss: 2.4289 - val_acc: 0.4880
# Epoch 44/50
# 50000/50000 [==============================] - 4s 79us/step - loss: 0.0980 - acc: 0.9834 - val_loss: 2.4411 - val_acc: 0.4899
# Epoch 45/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.0885 - acc: 0.9861 - val_loss: 2.4116 - val_acc: 0.4960
# Epoch 46/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 0.0804 - acc: 0.9882 - val_loss: 2.4275 - val_acc: 0.4918
# Epoch 47/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.0713 - acc: 0.9906 - val_loss: 2.5011 - val_acc: 0.5051
# Epoch 48/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.0623 - acc: 0.9933 - val_loss: 2.6366 - val_acc: 0.4926
# Epoch 49/50
# 50000/50000 [==============================] - 4s 81us/step - loss: 0.0590 - acc: 0.9937 - val_loss: 2.5214 - val_acc: 0.4977
# Epoch 50/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 0.0516 - acc: 0.9947 - val_loss: 2.5636 - val_acc: 0.4917

# %%
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    x = BatchNormalization()(input_layer)
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
        else:

            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
BATCH_SIZE=1024
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,751,178
# Trainable params: 1,745,034
# Non-trainable params: 6,144
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.9550 - acc: 0.3018 - val_loss: 1.7177 - val_acc: 0.3902
# Epoch 2/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 1.6257 - acc: 0.4306 - val_loss: 1.5824 - val_acc: 0.4404
# Epoch 3/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.5052 - acc: 0.4737 - val_loss: 1.5189 - val_acc: 0.4605
# Epoch 4/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.4187 - acc: 0.5057 - val_loss: 1.4646 - val_acc: 0.4808
# Epoch 5/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.3460 - acc: 0.5347 - val_loss: 1.4380 - val_acc: 0.4930
# Epoch 6/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.2802 - acc: 0.5580 - val_loss: 1.4098 - val_acc: 0.5018
# Epoch 7/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 1.2202 - acc: 0.5802 - val_loss: 1.3964 - val_acc: 0.5085
# Epoch 8/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.1605 - acc: 0.6027 - val_loss: 1.3786 - val_acc: 0.5126
# Epoch 9/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.1046 - acc: 0.6227 - val_loss: 1.3733 - val_acc: 0.5215
# Epoch 10/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 1.0483 - acc: 0.6440 - val_loss: 1.3711 - val_acc: 0.5222
# Epoch 11/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.9952 - acc: 0.6630 - val_loss: 1.3757 - val_acc: 0.5209
# Epoch 12/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.9418 - acc: 0.6826 - val_loss: 1.3804 - val_acc: 0.5227
# Epoch 13/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.8923 - acc: 0.7002 - val_loss: 1.3888 - val_acc: 0.5250
# Epoch 14/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.8405 - acc: 0.7202 - val_loss: 1.4083 - val_acc: 0.5244
# Epoch 15/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.7904 - acc: 0.7375 - val_loss: 1.4469 - val_acc: 0.5194
# Epoch 16/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.7406 - acc: 0.7576 - val_loss: 1.4523 - val_acc: 0.5239
# Epoch 17/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.6922 - acc: 0.7733 - val_loss: 1.4728 - val_acc: 0.5225
# Epoch 18/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.6438 - acc: 0.7923 - val_loss: 1.5217 - val_acc: 0.5171
# Epoch 19/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.5986 - acc: 0.8078 - val_loss: 1.5404 - val_acc: 0.5220
# Epoch 20/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.5503 - acc: 0.8268 - val_loss: 1.5843 - val_acc: 0.5129
# Epoch 21/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.5078 - acc: 0.8414 - val_loss: 1.6488 - val_acc: 0.5092
# Epoch 22/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.4680 - acc: 0.8573 - val_loss: 1.6829 - val_acc: 0.5110
# Epoch 23/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.4263 - acc: 0.8719 - val_loss: 1.7283 - val_acc: 0.5109
# Epoch 24/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.3844 - acc: 0.8871 - val_loss: 1.7894 - val_acc: 0.5121
# Epoch 25/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.3557 - acc: 0.8979 - val_loss: 1.8405 - val_acc: 0.5111
# Epoch 26/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.3206 - acc: 0.9080 - val_loss: 1.8811 - val_acc: 0.5110
# Epoch 27/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.2867 - acc: 0.9215 - val_loss: 1.9284 - val_acc: 0.5143
# Epoch 28/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.2619 - acc: 0.9284 - val_loss: 2.0099 - val_acc: 0.5089
# Epoch 29/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.2443 - acc: 0.9344 - val_loss: 2.0639 - val_acc: 0.5110
# Epoch 30/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.2112 - acc: 0.9469 - val_loss: 2.1259 - val_acc: 0.5089
# Epoch 31/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.1888 - acc: 0.9540 - val_loss: 2.2026 - val_acc: 0.5097
# Epoch 32/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.1719 - acc: 0.9598 - val_loss: 2.2591 - val_acc: 0.5045
# Epoch 33/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.1577 - acc: 0.9643 - val_loss: 2.2860 - val_acc: 0.5074
# Epoch 34/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.1300 - acc: 0.9739 - val_loss: 2.3542 - val_acc: 0.5115
# Epoch 35/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.1124 - acc: 0.9789 - val_loss: 2.4629 - val_acc: 0.5026
# Epoch 36/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.1031 - acc: 0.9807 - val_loss: 2.4926 - val_acc: 0.5109
# Epoch 37/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0883 - acc: 0.9852 - val_loss: 2.5098 - val_acc: 0.5108
# Epoch 38/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 0.0722 - acc: 0.9902 - val_loss: 2.5623 - val_acc: 0.5143
# Epoch 39/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0610 - acc: 0.9931 - val_loss: 2.6200 - val_acc: 0.5086
# Epoch 40/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0538 - acc: 0.9941 - val_loss: 2.6639 - val_acc: 0.5102
# Epoch 41/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0465 - acc: 0.9958 - val_loss: 2.7329 - val_acc: 0.5059
# Epoch 42/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0408 - acc: 0.9971 - val_loss: 2.7475 - val_acc: 0.5111
# Epoch 43/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0357 - acc: 0.9974 - val_loss: 2.7832 - val_acc: 0.5098
# Epoch 44/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0301 - acc: 0.9984 - val_loss: 2.8313 - val_acc: 0.5139
# Epoch 45/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0270 - acc: 0.9987 - val_loss: 2.8727 - val_acc: 0.5096
# Epoch 46/50
# 50000/50000 [==============================] - 5s 109us/step - loss: 0.0234 - acc: 0.9992 - val_loss: 2.9057 - val_acc: 0.5103
# Epoch 47/50
# 50000/50000 [==============================] - 5s 108us/step - loss: 0.0214 - acc: 0.9995 - val_loss: 2.9356 - val_acc: 0.5161
# Epoch 48/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.0186 - acc: 0.9995 - val_loss: 2.9564 - val_acc: 0.5111
# Epoch 49/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 0.0173 - acc: 0.9996 - val_loss: 3.0066 - val_acc: 0.5101
# Epoch 50/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.0157 - acc: 0.9997 - val_loss: 3.0260 - val_acc: 0.5130

# %%
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
